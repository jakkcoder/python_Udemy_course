# %% [markdown]
# ### Installing matplotlib
#
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Generating random dataset for plots

# %%
sample =np.random.random_sample((2,10))
sample
# Out:
# array([[0.83983721, 0.06772099, 0.70711339, 0.68075372, 0.14674506,
#         0.71338632, 0.8736808 , 0.15092957, 0.50375138, 0.52562567],
#        [0.66388841, 0.21186862, 0.23663569, 0.93621127, 0.11391722,
#         0.3298551 , 0.96090641, 0.35956517, 0.28500251, 0.22001402]])

# %%
sample[0]
# Out:
# array([0.83983721, 0.06772099, 0.70711339, 0.68075372, 0.14674506,
#        0.71338632, 0.8736808 , 0.15092957, 0.50375138, 0.52562567])

# %%
sample[1]
# Out:
# array([0.66388841, 0.21186862, 0.23663569, 0.93621127, 0.11391722,
#        0.3298551 , 0.96090641, 0.35956517, 0.28500251, 0.22001402])

# %%
plt.scatter(sample[0],sample[1])

# %%
plt.plot(sample[0],sample[1])
