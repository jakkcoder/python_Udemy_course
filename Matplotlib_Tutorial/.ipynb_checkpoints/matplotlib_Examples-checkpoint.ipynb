# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# ### Generating random dataset for plots

# %%
sample =np.random.random_sample((2,10))
sample
# Out:
# array([[0.39678064, 0.03683073, 0.85962146, 0.69622813, 0.2063041 ,
#         0.44494778, 0.2587019 , 0.32907685, 0.42203321, 0.07307761],
#        [0.45459863, 0.67295744, 0.58038731, 0.29015316, 0.45667363,
#         0.91580061, 0.43005802, 0.22747692, 0.28397109, 0.39071002]])

# %%
sample[0]
# Out:
# array([0.39678064, 0.03683073, 0.85962146, 0.69622813, 0.2063041 ,
#        0.44494778, 0.2587019 , 0.32907685, 0.42203321, 0.07307761])

# %%
sample[1]
# Out:
# array([0.45459863, 0.67295744, 0.58038731, 0.29015316, 0.45667363,
#        0.91580061, 0.43005802, 0.22747692, 0.28397109, 0.39071002])

# %% [markdown]
# ### Line plot

# %%
plt.plot(sample[0],sample[1])

# %% [markdown]
# ### Scatter plot

# %%
plt.scatter(sample[0],sample[1])

# %% [markdown]
# ### Barchart

# %%
plt.bar(range(len(sample[0])),sample[0])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Barchart horigental

# %%
plt.barh(range(len(sample[0])),sample[0])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# https://matplotlib.org/3.2.1/tutorials/introductory/sample_plots.html
