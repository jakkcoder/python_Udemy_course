# %% [markdown]
# ### Installing matplotlib
#
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Generating random dataset for plots

# %%
sample =np.random.random_sample((2,10))
sample
# Out:
# array([[0.12609638, 0.42861756, 0.56089976, 0.08259211, 0.29537481,
#         0.96619378, 0.25802438, 0.12249284, 0.42633895, 0.97074054],
#        [0.51384018, 0.64027903, 0.97624443, 0.52166981, 0.1476989 ,
#         0.88294871, 0.12773596, 0.1670887 , 0.92228249, 0.1801986 ]])

# %%
sample[0]
# Out:
# array([0.12609638, 0.42861756, 0.56089976, 0.08259211, 0.29537481,
#        0.96619378, 0.25802438, 0.12249284, 0.42633895, 0.97074054])

# %%
sample[1]
# Out:
# array([0.51384018, 0.64027903, 0.97624443, 0.52166981, 0.1476989 ,
#        0.88294871, 0.12773596, 0.1670887 , 0.92228249, 0.1801986 ])

# %%
plt.scatter(sample[0],sample[1])

# %%
plt.plot(sample[0],sample[1])
